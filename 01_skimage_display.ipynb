# %%
from skimage import io
img = io.imread('puppy.jpg')
io.imshow(img)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16104\3114751994.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img)
